# %% [markdown]
# Vorlesung vom 12.10.2023

# %%
t = [-2, -1 , 0 , 1 ,2]
for i in t:
    x = (i * i) - 2 * i
    y = (i + 1)
    print(f'{x}, {y}\n')
# Out:
# 8, -1
#
# 3, 0
#
# 0, 1
#
# -1, 2
#
# 0, 3

# %% [markdown]
# Euklidische Norm

# %%
import numpy as np
import math as m

v = [2, 3]

print(np.linalg.norm(v))
print(m.sqrt(m.pow(v[0], 2) + m.pow(v[1], 2)))
# Out:
# 3.605551275463989
# 3.605551275463989

# %% [markdown]
# Ein Kreis 🙂

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2 * np.pi, 0.01)
x = np.cos(t)
y = np.sin(t)

fig, ax = plt.subplots()
ax.plot(x, y)

ax.grid()
ax.set_aspect(1)

plt.show()
