# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m

# Data for plotting
t = np.arange(-2.5, 2.5, 0.01)
x = np.power(t, 2)
y = np.power(t, 3) - 3 * t

fig, ax = plt.subplots()
ax.plot(x, y)

ax.grid()

plt.show()
